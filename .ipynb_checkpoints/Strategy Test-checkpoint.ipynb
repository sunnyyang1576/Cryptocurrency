# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np

# %%
from src.PortfolioIndicator import PortfolioIndicator
from src.PortfolioConstructor import PortfolioConstructor

# %% [markdown]
# ### Import Data

# %%
data_directory = "data/"
file = "all_cryptocurrency_price_data.csv"

# %%
df = pd.read_csv(data_directory+file)
df.index = pd.to_datetime(df.iloc[:,0])
df = df.iloc[:,1:]

# %% [markdown]
# ### Check the number of asset available at each time stamp

# %%
df.shape
# Out:
# (1400, 299)

# %%
missing_value_date = df.isna().apply(sum,axis=1)
missing_value_date.plot(figsize=(20,10),grid=True)
# Out:
# <AxesSubplot:xlabel='Unnamed: 0'>

# %% [markdown]
# ### Select the Asset Universe

# %% [markdown]
# #### Select an initial date for which there are enough number of assets for testing

# %%
initial_date = "2019-01-01"

# %%
sub_df = df[df.index > initial_date]
sub_df = sub_df.fillna(method="ffill")
complete_sub_df = sub_df.dropna(axis=1)

# %% [markdown]
# #### Create Two universe based on the price

# %%
small_threshold = 10
big_threshold = 1

# %%
small_complete_df = complete_sub_df.iloc[:,list((complete_sub_df.iloc[0,:]<small_threshold))]

# %%
big_complete_df = complete_sub_df.iloc[:,list((complete_sub_df.iloc[0,:]>big_threshold))]

# %%
complete_sub_df.shape
# Out:
# (699, 172)

# %%
small_complete_df.shape
# Out:
# (699, 160)

# %%
big_complete_df.shape
# Out:
# (699, 39)

# %% [markdown]
# ### Momentum Strategy Test

# %%
universe_df = complete_sub_df

# %% [markdown]
# #### Calculate the Signal

# %% [markdown]
# Define the parameter for the strategy.
# 1. momentum_period : the number of days to look back
# 2. waiting_period : number of days to wait before make a transaction

# %%
momentum_period = 3
waiting_time = 1

# %% [markdown]
# This steps calculate the return of the asset between the close of the current day and the close of the looking back day

# %%
temp_df = universe_df.pct_change(periods=momentum_period)

# %% [markdown]
# Because we get this signal at the end of the day, so we can not execute transaction on that day.
#
# We have to wait for another day to execute transaction. So we shift the signal one day forward .
#
# For example: for VIBE, the first signal is obtained at the end of Jan.5th.
#
# This signal is used to determine transaction on the Jan.6th.
#
# So we shift the signal one day forward to represent the fact that we use this signal on Jan.6th.

# %%
temp_df = temp_df.shift(1)

# %% [markdown]
# We then drop the missing value from the dataset.

# %%
temp_df = temp_df.dropna()

# %% [markdown]
# We could achieve previous steps in an aggregate command.

# %%
complete_ret_sub_df = universe_df.pct_change(periods=momentum_period).shift(waiting_time).dropna()

# %% [markdown]
# ### Portfolio Construciton

# %% [markdown]
# #### Reframe the dataset

# %% [markdown]
# To use the portfolio construction class, we have to reshape the dataset to a long panel dataset.

# %%
complete_ret_sub_df_long = complete_ret_sub_df.stack()

# %%
signal_df = complete_ret_sub_df_long.index.to_frame()
signal_df.index = range(0,signal_df.shape[0])
signal_df["momentum"] = list(complete_ret_sub_df_long)
signal_df.columns=["date","ticker","momentum"]

# %% [markdown]
# #### Create Portfolio Indicator

# %% [markdown]
# We firstly need to create a  portfolio indicator series which indicates which portfolio the asset belongs to at certain date.
#
#
# This can be achieved by using the class PortfolioIndicator
#
# This class requires a list of rebalance date, a dataframe that contains the signal, the name of the signal, and the number of portfolios.

# %% [markdown]
# Here, we choose a daily rebalance strategy.
#
# At the end of each day, we rebalance the strategy.
#
# We create 5 portfolio using equal weighted method.

# %%
rebalance_date_series = list(complete_ret_sub_df.index)

# %%
portfolio_indicator = PortfolioIndicator()

# %%
portfolio_indicator = portfolio_indicator.create_indicator(signal_df,"momentum",rebalance_date_series,5)

# %% [markdown]
# #### Example of Portfolio

# %% [markdown]
# Example Date : 2019-01-06

# %%
sub_df = portfolio_indicator[portfolio_indicator.date=="2019-01-06"]

# %%
top_portfolio = sub_df["ticker"][sub_df["momentum_indicator"]==4]
bottom_portfolio = sub_df["ticker"][sub_df["momentum_indicator"]==0]

# %% [markdown]
# Check the signal

# %%
top_signal = complete_ret_sub_df[list(top_portfolio)].iloc[0,:]

# %%
bottom_signal = complete_ret_sub_df[list(bottom_portfolio)].iloc[0,:]

# %%
top_signal.mean()
# Out:
# 0.08376442369676143

# %%
bottom_signal.mean()
# Out:
# -0.07123180492364492

# %%
top_signal.median()
# Out:
# 0.04157317681090511

# %%
bottom_signal.median()
# Out:
# -0.060040502144995234

# %%
complete_ret_sub_df.index[0]
# Out:
# Timestamp('2019-01-06 00:00:00+0000', tz='UTC')

# %% [markdown]
# Check the return

# %%
complete_sub_df_1_day_return = universe_df.pct_change().dropna()

# %%
complete_sub_df_1_day_return
# Out:
#                                VIBE       BCD       NAS       VET       BCH  \
# Unnamed: 0
# 2019-01-03 00:00:00+00:00 -0.020507 -0.040837 -0.056507 -0.056983 -0.062782
# 2019-01-04 00:00:00+00:00  0.086113  0.001981  0.012124  0.019035 -0.001719
# 2019-01-05 00:00:00+00:00  0.078887  0.020718 -0.000034 -0.004472 -0.002309
# 2019-01-06 00:00:00+00:00  0.011818  0.049254  0.037042  0.072453  0.038697
# 2019-01-07 00:00:00+00:00 -0.032628 -0.040117 -0.008068 -0.043537 -0.032439
# ...                             ...       ...       ...       ...       ...
# 2020-11-26 00:00:00+00:00 -0.166528 -0.096881 -0.133012 -0.121914 -0.131998
# 2020-11-27 00:00:00+00:00  0.009187  0.002786 -0.028221 -0.007197 -0.021959
# 2020-11-28 00:00:00+00:00  0.057147  0.026345  0.017922  0.059476  0.039945
# 2020-11-29 00:00:00+00:00  0.003246  0.011122  0.008984 -0.013848  0.031204
# 2020-11-30 00:00:00+00:00  0.033417  0.052423  0.026212  0.053536  0.112081
#
#                                CTXC    ONTGAS       POA       BLZ       PPT  \
# Unnamed: 0
# 2019-01-03 00:00:00+00:00 -0.038608 -0.013490 -0.030269 -0.044713 -0.056224
# 2019-01-04 00:00:00+00:00  0.025790 -0.048615  0.047155  0.063915  0.006464
# 2019-01-05 00:00:00+00:00  0.003956  0.000799 -0.011276 -0.021437  0.025413
# 2019-01-06 00:00:00+00:00  0.284719 -0.021715  0.054478  0.068612  0.052967
# 2019-01-07 00:00:00+00:00 -0.063994  0.044851 -0.013696 -0.056020 -0.022435
# ...                             ...       ...       ...       ...       ...
# 2020-11-26 00:00:00+00:00 -0.114979 -0.300576 -0.169641 -0.156842 -0.116152
# 2020-11-27 00:00:00+00:00 -0.015132 -0.066878  0.006794 -0.032403  0.016241
# 2020-11-28 00:00:00+00:00  0.028998  0.254622  0.034277 -0.002837  0.057838
# 2020-11-29 00:00:00+00:00  0.003238  0.004525 -0.019545  0.008692 -0.020704
# 2020-11-30 00:00:00+00:00  0.019300 -0.057542  0.002115  0.039567  0.186296
#
#                            ...       VIB      NPXS           EVX       MCO  \
# Unnamed: 0                 ...
# 2019-01-03 00:00:00+00:00  ... -0.021548 -0.037124 -2.779740e-02 -0.018832
# 2019-01-04 00:00:00+00:00  ...  0.035140  0.042470  6.002643e-02  0.020526
# 2019-01-05 00:00:00+00:00  ... -0.016475 -0.018449 -3.325640e-02  0.103294
# 2019-01-06 00:00:00+00:00  ...  0.058857  0.069522  5.310210e-02  0.034963
# 2019-01-07 00:00:00+00:00  ... -0.000881 -0.042157 -4.857734e-02  0.003455
# ...                        ...       ...       ...           ...       ...
# 2020-11-26 00:00:00+00:00  ... -0.142409 -0.092958 -1.130802e-01 -0.220452
# 2020-11-27 00:00:00+00:00  ... -0.003020  0.002642  8.473809e-07  0.091717
# 2020-11-28 00:00:00+00:00  ...  0.049396  0.000000  3.219404e-02 -0.055379
# 2020-11-29 00:00:00+00:00  ...  0.081154  0.046986 -2.433462e-02 -0.082567
# 2020-11-30 00:00:00+00:00  ... -0.029600  0.000107  3.565939e-02 -0.011427
#
#                                 CND       TRX       ELF       DCR       BTC  \
# Unnamed: 0
# 2019-01-03 00:00:00+00:00 -0.021314  0.003068 -0.010352 -0.017922 -0.034209
# 2019-01-04 00:00:00+00:00  0.033073  0.037731  0.032105  0.024468  0.013710
# 2019-01-05 00:00:00+00:00  0.005732  0.083543 -0.019060 -0.004662 -0.008939
# 2019-01-06 00:00:00+00:00  0.112359  0.028707  0.060217  0.063627  0.061779
# 2019-01-07 00:00:00+00:00 -0.062356  0.006384 -0.043233 -0.032837 -0.013898
# ...                             ...       ...       ...       ...       ...
# 2020-11-26 00:00:00+00:00 -0.115270 -0.107583 -0.130237  0.003042 -0.084293
# 2020-11-27 00:00:00+00:00 -0.022005 -0.005642  0.040591  0.046715 -0.001834
# 2020-11-28 00:00:00+00:00  0.013835  0.034145  0.027586 -0.002154  0.032988
# 2020-11-29 00:00:00+00:00 -0.015155  0.011506 -0.013303  0.099703  0.028290
# 2020-11-30 00:00:00+00:00  0.056509  0.048470  0.017294  0.031654  0.080125
#
#                               STORJ
# Unnamed: 0
# 2019-01-03 00:00:00+00:00 -0.020033
# 2019-01-04 00:00:00+00:00  0.007449
# 2019-01-05 00:00:00+00:00  0.012950
# 2019-01-06 00:00:00+00:00  0.043191
# 2019-01-07 00:00:00+00:00  0.006554
# ...                             ...
# 2020-11-26 00:00:00+00:00 -0.152022
# 2020-11-27 00:00:00+00:00 -0.024698
# 2020-11-28 00:00:00+00:00  0.032203
# 2020-11-29 00:00:00+00:00 -0.003118
# 2020-11-30 00:00:00+00:00  0.029311
#
# [698 rows x 172 columns]

# %%
top_return = complete_sub_df_1_day_return.loc[complete_ret_sub_df.index[0],list(top_portfolio)]
bottom_return = complete_sub_df_1_day_return.loc[complete_ret_sub_df.index[0],list(bottom_portfolio)]

# %%
top_return.mean()
# Out:
# 0.037827320639233504

# %%
bottom_return.mean()
# Out:
# 0.05399171009955972

# %%
top_return.median()
# Out:
# 0.034468753751165426

# %%
bottom_return.median()
# Out:
# 0.05816611578945685

# %% [markdown]
# ### Calculate Portfolio Strategy Return

# %%
complete_sub_df_1 = universe_df.pct_change().dropna()
complete_sub_df_1_long = complete_sub_df_1.stack()

# %%
index_df = complete_sub_df_1_long.index.to_frame()
index_df["ret"] = complete_sub_df_1_long
index_df.index=range(0,index_df.shape[0])
index_df.columns = ["date","ticker","ret"]

# %%
merge_df = index_df.merge(portfolio_indicator,on=["date","ticker"])

# %%
portfolio_constructor = PortfolioConstructor(merge_df)

# %%
strategy_ret_df = portfolio_constructor.create_portfolio_series("momentum_indicator",equal_weight=True)

# %%
strategy_ret_df.describe()
# Out:
# momentum_indicator           0           1           2           3           4
# count               693.000000  693.000000  693.000000  693.000000  693.000000
# mean                  0.003017    0.001213    0.002894    0.002659    0.002914
# std                   0.042496    0.040232    0.044485    0.041264    0.045227
# min                  -0.412499   -0.466707   -0.438980   -0.458587   -0.260439
# 25%                  -0.013188   -0.015129   -0.014780   -0.014808   -0.018188
# 50%                   0.004109    0.003089    0.005335    0.005135    0.003578
# 75%                   0.022703    0.022026    0.021796    0.021253    0.023221
# max                   0.264519    0.157149    0.473821    0.190791    0.536750

# %%
strategy_cum_ret_df = (strategy_ret_df+1).cumprod()

# %%
strategy_cum_ret_df.iloc[0:400,:].plot()

# %%
strategy_ret_df.mean()/strategy_ret_df.std()
# Out:
# momentum_indicator
# 0    0.070985
# 1    0.030153
# 2    0.065055
# 3    0.064430
# 4    0.064429
# dtype: float64
