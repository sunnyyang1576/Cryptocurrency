# %%
import pandas as pd
import numpy as np
from yahoo_fin.stock_info import get_data

# %%
import time

# %% [markdown]
# An Instruction :
# https://algotrading101.com/learn/yahoo-finance-api-guide/

# %%
ticker = "BTC-USD"
start_date = "01/01/2019"
end_date = "01/01/2020"

# %%
get_data(ticker=ticker,
         start_date=start_date,
         end_date=end_date,
         index_as_date=True,
         interval="1d")
# Out:
#                    open         high          low        close     adjclose  \
# 2019-01-01  3746.713379  3850.913818  3707.231201  3843.520020  3843.520020
# 2019-01-02  3849.216309  3947.981201  3817.409424  3943.409424  3943.409424
# 2019-01-03  3931.048584  3935.685059  3826.222900  3836.741211  3836.741211
# 2019-01-04  3832.040039  3865.934570  3783.853760  3857.717529  3857.717529
# 2019-01-05  3851.973877  3904.903076  3836.900146  3845.194580  3845.194580
# ...                 ...          ...          ...          ...          ...
# 2019-12-28  7289.031250  7399.041016  7286.905273  7317.990234  7317.990234
# 2019-12-29  7317.647461  7513.948242  7279.865234  7422.652832  7422.652832
# 2019-12-30  7420.272949  7454.824219  7276.308105  7292.995117  7292.995117
# 2019-12-31  7294.438965  7335.290039  7169.777832  7193.599121  7193.599121
# 2020-01-01  7194.892090  7254.330566  7174.944336  7200.174316  7200.174316
#
#                  volume   ticker
# ...

# %% [markdown]
# ### Get all crypto ticker

# %%
with open("data/yahoo_finance_crypto_list.txt") as f:
    
    ticker_list = f.readlines()
    
    ticker_list = [ticker.strip() for ticker in ticker_list]

# %% [markdown]
# ### Get All Crypto Price

# %%
start_date = "01/01/2015"
end_date = "01/01/2020"

# %%
price_dic = {}

for ticker in ticker_list:
    
    price_df = get_data(ticker=ticker,
                        start_date=None,
                        end_date=None,
                        index_as_date=True,
                        interval="1d")
    
    price_dic[ticker] = price_df
    
    time.sleep(1)

# %%
price_dic["BTC-USD"]
# Out:
#                     open          high           low         close  \
# 2014-09-16    465.864014    468.174011    452.421997    457.334015
# 2014-09-17    456.859985    456.859985    413.104004    424.440002
# 2014-09-18    424.102997    427.834991    384.532013    394.795990
# 2014-09-19    394.673004    423.295990    389.882996    408.903992
# 2014-09-20    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2020-12-30  27360.089844  28937.740234  27360.089844  28840.953125
# 2020-12-31  28841.574219  29244.876953  28201.992188  29001.720703
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32741.494141  34550.718750  32055.917969  33931.503906
#
#                 adjclose       volume   ticker
# 2014-09-16    457.334015     21056800  BTC-USD
# 2014-09-17    424.440002     34483200  BTC-USD
# ...

# %%
price_df_list = [price_dic[ticker] for ticker in ticker_list]

# %%
price_df = pd.concat(price_df_list,axis=0)

# %%
price_df.to_csv("data/yahoo_finance_crypto_price_df.csv")
