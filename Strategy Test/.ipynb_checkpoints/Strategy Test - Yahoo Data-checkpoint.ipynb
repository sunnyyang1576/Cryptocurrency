# %% [markdown]
# ### Import Library

# %%
import pandas as pd
import numpy as np

# %%
from src.PortfolioIndicator import PortfolioIndicator
from src.PortfolioConstructor import PortfolioConstructor

# %% [markdown]
# ### Import Data

# %%
data_directory = "data/"
file = "yahoo_data_filter_0_0_1.csv"

# %%
df = pd.read_csv(data_directory+file)
df.index = pd.to_datetime(df.iloc[:,0])
df = df.iloc[:,1:]

# %%
big_asset_list = list(df.iloc[0,:][df.iloc[0,:]>1].index)
small_asset_list = list(df.iloc[0,:][df.iloc[0,:]<=1].index)

# %% [markdown]
# ### Momentum Strategy Test

# %%
universe_df = df

# %% [markdown]
# #### Calculate the Signal

# %% [markdown]
# Define the parameter for the strategy.
# 1. momentum_period : the number of days to look back
# 2. waiting_period : number of days to wait before make a transaction

# %%
momentum_period = 3
waiting_time = 1

# %%
complete_ret_sub_df = universe_df.pct_change(periods=momentum_period).shift(waiting_time).dropna()

# %% [markdown]
# ### Portfolio Construciton

# %% [markdown]
# #### Reframe the dataset

# %% [markdown]
# To use the portfolio construction class, we have to reshape the dataset to a long panel dataset.

# %%
complete_ret_sub_df_long = complete_ret_sub_df.stack()

# %%
signal_df = complete_ret_sub_df_long.index.to_frame()
signal_df.index = range(0,signal_df.shape[0])
signal_df["momentum"] = list(complete_ret_sub_df_long)
signal_df.columns=["date","ticker","momentum"]

# %%
signal_df
# Out:
#             date    ticker  momentum
# 0     2018-01-04   ADA-USD  0.500163
# 1     2018-01-04   ADX-USD  0.024532
# 2     2018-01-04    AE-USD  0.156634
# 3     2018-01-04  ARDR-USD  0.136007
# 4     2018-01-04   ARK-USD  0.078317
# ...          ...       ...       ...
# 80877 2021-01-03   XVG-USD -0.050796
# 80878 2021-01-03   XZC-USD -0.059965
# 80879 2021-01-03   ZEC-USD -0.099644
# 80880 2021-01-03   ZEN-USD  0.082968
# 80881 2021-01-03   ZRX-USD  0.001691
#
# [80882 rows x 3 columns]

# %% [markdown]
# #### Create Portfolio Indicator

# %%
rebalance_date_series = list(complete_ret_sub_df.index)

# %%
portfolio_indicator = PortfolioIndicator()
# Out:
# initialized.

# %%
portfolio_indicator = portfolio_indicator.create_indicator(signal_df,"momentum",rebalance_date_series,5)

# %% [markdown]
# #### Example of Portfolio

# %% [markdown]
# Example Date : 2019-01-06

# %%
sub_df = portfolio_indicator[portfolio_indicator.date=="2018-02-01"]

# %%
top_portfolio = sub_df["ticker"][sub_df["momentum_indicator"]==4]
bottom_portfolio = sub_df["ticker"][sub_df["momentum_indicator"]==0]

# %%
complete_ret_sub_df
# Out:
#              ADA-USD   ADX-USD    AE-USD  ARDR-USD   ARK-USD   ATB-USD  \
# date
# 2018-01-04  0.500163  0.024532  0.156634  0.136007  0.078317  0.095065
# 2018-01-05  0.529005 -0.081523  0.389596  0.108509 -0.064384  0.066594
# 2018-01-06  0.277250 -0.163454  0.537874 -0.156383 -0.134631  0.403393
# 2018-01-07 -0.048636  0.001064  0.615266 -0.131545  0.035458  0.383550
# 2018-01-08 -0.094783  0.104372  0.475321  0.022069  0.131682  1.880146
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-30  0.217587  0.057749 -0.027132 -0.010070  0.023502  0.035159
# 2020-12-31  0.191798  0.037101 -0.073401  0.112606 -0.041483  0.095186
# 2021-01-01  0.026381  0.142912 -0.116860  0.061956 -0.016753 -0.143384
# 2021-01-02 -0.087499  0.172343 -0.059855  0.272807  0.044783 -0.141211
# 2021-01-03 -0.035956  0.084696 -0.026557  0.055930  0.003385 -0.109379
#
#              BAT-USD   BCH-USD   BNB-USD   BNT-USD  ...   XEM-USD   XLM-USD  \
# date                                                ...
# 2018-01-04  0.579850  0.029877  0.104255  0.252175  ...  0.731328  1.484302
# 2018-01-05  0.333319 -0.000970  0.094999  0.316504  ...  0.579467  0.508412
# 2018-01-06 -0.018496 -0.046669  0.687892  0.190175  ...  0.372020  0.173428
# 2018-01-07  0.019480  0.068218  1.386754  0.119293  ... -0.075893 -0.207851
# 2018-01-08  0.195715  0.146779  1.024834  0.160994  ...  0.120324 -0.033706
# ...              ...       ...       ...       ...  ...       ...       ...
# 2020-12-30 -0.036104  0.093736  0.163565  0.048275  ... -0.056388 -0.055983
# 2020-12-31 -0.033307  0.060997  0.137994  0.034534  ... -0.182434 -0.090087
# 2021-01-01 -0.053256 -0.052582  0.042726 -0.064372  ... -0.113793 -0.110858
# 2021-01-02 -0.002836 -0.031451 -0.026900 -0.034646  ... -0.003817 -0.046154
# 2021-01-03  0.011501 -0.011728  0.002761 -0.030945  ...  0.053598 -0.031025
#
#              XMR-USD   XRP-USD   XUC-USD   XVG-USD   XZC-USD   ZEC-USD  \
# date
# 2018-01-04  0.180608  0.349826  0.116160 -0.347615  0.106452  0.151091
# 2018-01-05  0.122728  0.336926  0.160677  0.019554 -0.067274  0.031180
# 2018-01-06  0.003962  0.228873  0.192606  0.249881 -0.175955  0.009167
# 2018-01-07  0.098791 -0.003671  0.144747  0.199434 -0.124324  0.313407
# 2018-01-08  0.139643  0.056678  0.067086  0.143061 -0.031187  0.479798
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-30 -0.038981 -0.250248  0.000095  0.056317 -0.029091  0.006225
# 2020-12-31  0.013444 -0.251594 -0.085285 -0.005151 -0.099988 -0.050921
# 2021-01-01 -0.059553 -0.113377  0.015127 -0.054374 -0.005471 -0.072826
# 2021-01-02 -0.157053  0.074594  0.073924 -0.015002 -0.056278 -0.146453
# 2021-01-03 -0.101996  0.046390 -0.015449 -0.050796 -0.059965 -0.099644
#
#              ZEN-USD   ZRX-USD
# date
# 2018-01-04 -0.161317  0.087919
# 2018-01-05 -0.022368  0.190889
# 2018-01-06 -0.119370  0.246788
# 2018-01-07  0.069886  0.400605
# 2018-01-08 -0.048557  0.304527
# ...              ...       ...
# 2020-12-30 -0.027068  0.031714
# 2020-12-31 -0.135921 -0.036408
# 2021-01-01 -0.047526 -0.059683
# 2021-01-02  0.018827  0.026020
# 2021-01-03  0.082968  0.001691
#
# [1093 rows x 74 columns]

# %% [markdown]
# Check the signal

# %%
top_signal = complete_ret_sub_df[list(top_portfolio)].loc[complete_ret_sub_df.index=="2018-02-01",:].iloc[0,:]

# %%
bottom_signal = complete_ret_sub_df[list(bottom_portfolio)].loc[complete_ret_sub_df.index=="2018-02-01",:].iloc[0,:]

# %%
top_signal
# Out:
# AE-USD     -0.083533
# DCR-USD     0.049146
# DGD-USD    -0.022056
# GAS-USD     0.113058
# KNC-USD     0.043801
# LSK-USD     0.130627
# NANO-USD    0.016912
# NEO-USD    -0.042049
# OMG-USD    -0.078828
# PPT-USD    -0.052839
# QTUM-USD   -0.037564
# USDT-USD    0.001501
# VERI-USD    0.008672
# ZEN-USD    -0.038609
# ZRX-USD    -0.066215
# Name: 2018-02-01 00:00:00, dtype: float64

# %%
bottom_signal
# Out:
# ADA-USD     -0.225234
# ARDR-USD    -0.205378
# DNT-USD     -0.238842
# GNT-USD     -0.210568
# MGO-USD     -0.226700
# MONA-USD    -0.217442
# QASH-USD    -0.252927
# RLC-USD     -0.227554
# SC-USD      -0.248226
# SNGLS-USD   -0.213886
# SNT-USD     -0.222372
# STEEM-USD   -0.206938
# STORJ-USD   -0.231718
# XEM-USD     -0.243269
# XVG-USD     -0.240376
# Name: 2018-02-01 00:00:00, dtype: float64

# %%
top_signal.mean()
# Out:
# -0.0038650902506874567

# %%
bottom_signal.mean()
# Out:
# -0.22742853592665385

# %%
top_signal.median()
# Out:
# -0.022055959714042395

# %%
bottom_signal.median()
# Out:
# -0.2266995279328039

# %%
complete_ret_sub_df.index[0]
# Out:
# Timestamp('2018-01-04 00:00:00')

# %% [markdown]
# Check the return

# %%
complete_sub_df_1_day_return = universe_df.pct_change().dropna()

# %%
top_return = complete_sub_df_1_day_return.loc[complete_ret_sub_df.index[0],list(top_portfolio)]
bottom_return = complete_sub_df_1_day_return.loc[complete_ret_sub_df.index[0],list(bottom_portfolio)]

# %%
top_return.mean()
# Out:
# 0.037743945869530296

# %%
bottom_return.mean()
# Out:
# 0.029373092617984285

# %%
top_return.median()
# Out:
# 0.0220136249520948

# %%
bottom_return.median()
# Out:
# 0.03191740654353259

# %% [markdown]
# ### Calculate Portfolio Strategy Return

# %% [markdown]
# #### Prepare the daily return dataset for each asset

# %%
complete_sub_df_1 = universe_df.pct_change().dropna()
complete_sub_df_1_long = complete_sub_df_1.stack()

# %%
index_df = complete_sub_df_1_long.index.to_frame()
index_df["ret"] = complete_sub_df_1_long
index_df.index=range(0,index_df.shape[0])
index_df.columns = ["date","ticker","ret"]

# %%
return_df = index_df

# %% [markdown]
# #### Merge the return and indicator

# %%
merge_df = return_df.merge(portfolio_indicator,on=["date","ticker"])

# %% [markdown]
# #### Calculate strategy return

# %% [markdown]
# Initialize the portfolio return calculation class.
#
# The initialization of this class requires a dataframe.
#
# The dataframe should contain at least three columns.
#
# 1. Date
# 2. Ticker
# 3. Return
# 4. Portfolio Indicator

# %%
portfolio_constructor = PortfolioConstructor(merge_df)

# %%
strategy_ret_df = portfolio_constructor.create_portfolio_series("momentum_indicator",equal_weight=True)

# %% [markdown]
# #### Evaluate the performance of the strategy

# %%
strategy_ret_df.describe()
# Out:
# momentum_indicator            0            1            2            3  \
# count               1093.000000  1093.000000  1093.000000  1093.000000
# mean                   0.002781     0.000247     0.000501    -0.000089
# std                    0.048668     0.046598     0.047784     0.046207
# min                   -0.422170    -0.402881    -0.435741    -0.370701
# 25%                   -0.018698    -0.018132    -0.019329    -0.020315
# 50%                    0.005217     0.003671     0.004275     0.002923
# 75%                    0.025797     0.024701     0.024226     0.021642
# max                    0.196337     0.232386     0.194912     0.167851
#
# momentum_indicator            4
# count               1093.000000
# mean                  -0.002114
# std                    0.048783
# min                   -0.426906
# 25%                   -0.024205
# 50%                   -0.000324
# 75%                    0.023717
# max                    0.186447

# %%
strategy_ret_df.plot(kind="density",figsize=(20,10),xlim=(-0.5,0.5))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
strategy_cum_ret_df = (strategy_ret_df+1).cumprod()

# %%
strategy_cum_ret_df.iloc[0:,:].plot(figsize=(20,10),grid=True)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
strategy_cum_ret_df.iloc[0:700,:].plot(figsize=(20,10),grid=True)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
strategy_ret_df.mean()/strategy_ret_df.std()
# Out:
# momentum_indicator
# 0    0.057149
# 1    0.005308
# 2    0.010479
# 3   -0.001935
# 4   -0.043334
# dtype: float64

# %% [markdown]
# Create a Long Short Strategy

# %%
long_short_return = strategy_ret_df.iloc[:,0] - strategy_ret_df.iloc[:,4]

# %%
long_short_return.mean()
# Out:
# 0.004895264855685644

# %%
long_short_return.median()
# Out:
# 0.004673680167810952

# %%
long_short_return.mean()/long_short_return.std()
# Out:
# 0.1648096452585443

# %%
long_short_return.median()
# Out:
# 0.004673680167810952

# %%
factor_return = (long_short_return+1).cumprod()

# %%
factor_return[0:].plot()
# Out:
# <AxesSubplot:xlabel='date'>
